# %% [markdown]
# # Download bird songs
# A script to download bird sound files from the www.xeno-canto.org archives with metadata
# The program downloads all the files found with the search terms into subdirectory data/xeno-canto-dataset/searchTerm with corresponding json files.

# %%
import urllib.request, json
import sys
import os

savePath="./data/xeno-canto-dataset-full-all-Countries/"
bPath = "./data/"
basePath = "data/xeno-canto-dataset"

# %% [markdown]
# ## Defining necessary functions
# * Creates the subdirectory data/xeno-canto-dataset if necessary
# * Downloads and saves json files for number of pages in a query
# * and directory path to saved json's

# %%
def save_json(searchTerms, birdName, country):
    numPages = 1
    page = 1
    # create a path to save recordings
    path = bPath + birdName.replace(':', '') + "/" + country
    if not os.path.exists(path):
        print("Creating subdirectory " + path + " for downloaded files...")
        os.makedirs(path)
        # download a json file for every page found in a query
    while page < numPages + 1:
        print("Loading page " + str(page) + "...")
        url = 'https://www.xeno-canto.org/api/2/recordings?query={0}&page={1}'.format(searchTerms.replace(' ', '%20'),
                                                                                      page)
        print(url)
        jsonPage = urllib.request.urlopen(url)
        jsondata = json.loads(jsonPage.read().decode('utf-8'))
        filename = path + "/jsondata_p" + str(page) + ".json"
        with open(filename, 'w') as outfile:
            json.dump(jsondata, outfile)
        # check number of pages
        numPages = jsondata['numPages']
        page = page + 1
    print("Found ", numPages, " pages in total.")
    print("Saved json for ", (numPages - 1) * 500 + len(jsondata['recordings']), " files")
    return path

def read_data(searchTerm, path):
    data = []
    numPages = 1
    page = 1
    # read all pages and save results in a list
    while page < numPages + 1:
        # read file
        with open(path + "/jsondata_p" + str(page) + ".json", 'r') as jsonfile:
            jsondata = jsonfile.read()
        jsondata = json.loads(jsondata)
        # check number of pages
        numPages = jsondata['numPages']
        # find "recordings" in a json and save a list with a search term
        for k in range(len(jsondata['recordings'])):
            data.append(jsondata["recordings"][k][searchTerm])
        page = page + 1
    return data

def download(searchTerms, birdName, country):
    # create data/xeno-canto-dataset directory
    path = save_json(searchTerms, birdName, country)
    # get filenames: recording ID and bird name in latin from json
    filenamesID = read_data('id', path)
    filenamesCountry = read_data('cnt', path)

    fileaddress = read_data('file', path) #json file
    
    numfiles = len(filenamesID)
    print("A total of ", numfiles, " files will be downloaded")
    for i in range(0, numfiles):
        print("Saving file ", i + 1, "/", numfiles,
              path + "/" + birdName.replace(':', '') + filenamesID[i] + ".mp3")
        urllib.request.urlretrieve(fileaddress[i],
                                   path + "/" + birdName + filenamesID[i] + ".mp3")

# %% [markdown]
# ## Download
# Example download with all sounds type song, from bird list recorded in selected countries
#
# *example query*: query = "Dendrocopos major cnt:Poland type:song"
# can be downloaded as:
#
# download(query)
#
# Other options can be specified according to xeno-canto query list
# http://www.xeno-canto.org/explore?query=common+snipe

# %%
countries = ['France']
birds = [
         'Phoenicurus ochruros', #268
         'Turdus merula', #353
         'Phylloscopus collybita', #288
         'Phoenicurus phoenicurus', #163
         'Erithacus rubecula', #537
         'Parus major', #424
         'Alauda arvensis', #195
         'Turdus philomelos', #351
         'Troglodytes troglodytes', #331
         'Fringilla coelebs' #462
]

for country in countries:
    for bird in birds:
        download(bird + ' cnt:' + country + ' type:song', bird.replace(' ', ''), country)
for bird in birds:
    download(bird + ' type:song', bird.replace(' ', ''), 'countries')
# Out:
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=
mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/544405/download ./data/Corvuscorone/France/Corvuscorone544405.mp3
# Saving file  5 / 28 data/xeno-canto-datasetCorvuscorone538727.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/538727/download ./data/Corvuscorone/France/Corvuscorone538727.mp3
# Saving file  6 / 28 data/xeno-canto-datasetCorvuscorone537804.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/537804/download ./data/Corvuscorone/France/Corvuscorone537804.mp3
# Saving file  7 / 28 data/xeno-canto-datasetCorvuscorone536578.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/536578/download ./data/Corvuscorone/France/Corvuscorone536578.mp3
# Saving file  8 / 28 data/xeno-canto-datasetCorvuscorone536052.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/536052/download ./data/Corvuscorone/France/Corvuscorone536052.mp3
# Saving file  9 / 28 data/xeno-canto-datasetCorvuscorone388223.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/388223/download ./data/Corvuscorone/France/Corvuscorone388223.mp3
# Saving file  10 / 28 data/xeno-canto-datasetCorvuscorone879243.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/879243/download ./data/Corvuscorone/France/Corvuscorone879243.mp3
# Saving file  11 / 28 data/xeno-canto-datasetCorvuscorone689521.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/689521/download ./data/Corvuscorone/France/Corvuscorone689521.mp3
# Saving file  12 / 28 data/xeno-canto-datasetCorvuscorone689520.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/689520/download ./data/Corvuscorone/France/Corvuscorone689520.mp3
# Saving file  13 / 28 data/xeno-canto-datasetCorvuscorone689519.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/689519/download ./data/Corvuscorone/France/Corvuscorone689519.mp3
# Saving file  14 / 28 data/xeno-canto-datasetCorvuscorone689518.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/689518/download ./data/Corvuscorone/France/Corvuscorone689518.mp3
# Saving file  15 / 28 data/xeno-canto-datasetCorvuscorone648214.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/648214/download ./data/Corvuscorone/France/Corvuscorone648214.mp3
# Saving file  16 / 28 data/xeno-canto-datasetCorvuscorone642000.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/642000/download ./data/Corvuscorone/France/Corvuscorone642000.mp3
# Saving file  17 / 28 data/xeno-canto-datasetCorvuscorone550753.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/550753/download ./data/Corvuscorone/France/Corvuscorone550753.mp3
# Saving file  18 / 28 data/xeno-canto-datasetCorvuscorone550752.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/550752/download ./data/Corvuscorone/France/Corvuscorone550752.mp3
# Saving file  19 / 28 data/xeno-canto-datasetCorvuscorone544272.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/544272/download ./data/Corvuscorone/France/Corvuscorone544272.mp3
# Saving file  20 / 28 data/xeno-canto-datasetCorvuscorone526995.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/526995/download ./data/Corvuscorone/France/Corvuscorone526995.mp3
# Saving file  21 / 28 data/xeno-canto-datasetCorvuscorone344234.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/344234/download ./data/Corvuscorone/France/Corvuscorone344234.mp3
# Saving file  22 / 28 data/xeno-canto-datasetCorvuscorone337416.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/337416/download ./data/Corvuscorone/France/Corvuscorone337416.mp3
# Saving file  23 / 28 data/xeno-canto-datasetCorvuscorone191577.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/191577/download ./data/Corvuscorone/France/Corvuscorone191577.mp3
# Saving file  24 / 28 data/xeno-canto-datasetCorvuscorone542943.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/542943/download ./data/Corvuscorone/France/Corvuscorone542943.mp3
# Saving file  25 / 28 data/xeno-canto-datasetCorvuscorone542421.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org/542421/download ./data/Corvuscorone/France/Corvuscorone542421.mp3
# Saving file  26 / 28 data/xeno-canto-datasetCorvuscorone410027.mp3
# ./data/Corvuscorone/France
# https://xeno-canto.org
mp3
# ./data/Emberizacitrinella/countries
# https://xeno-canto.org/798299/download ./data/Emberizacitrinella/countries/Emberizacitrinella798299.mp3
# Saving file  40 / 2124 data/xeno-canto-datasetEmberizacitrinella796085.mp3
# ./data/Emberizacitrinella/countries
# https://xeno-canto.org/796085/download ./data/Emberizacitrinella/countries/Emberizacitrinella796085.mp3
# Saving file  41 / 2124 data/xeno-canto-datasetEmberizacitrinella793718.mp3
# ./data/Emberizacitrinella/countries
# https://xeno-canto.org/793718/download ./data/Emberizacitrinella/countries/Emberizacitrinella793718.mp3
# Saving file  42 / 2124 data/xeno-canto-datasetEmberizacitrinella793309.mp3
# ./data/Emberizacitrinella/countries
# https://xeno-canto.org/793309/download ./data/Emberizacitrinella/countries/Emberizacitrinella793309.mp3
# Saving file  43 / 2124 data/xeno-canto-datasetEmberizacitrinella791955.mp3
# ./data/Emberizacitrinella/countries
# https://xeno-canto.org/791955/download ./data/Emberizacitrinella/countries/Emberizacitrinella791955.mp3
# Saving file  44 / 2124 data/xeno-canto-datasetEmberizacitrinella791900.mp3
# ./data/Emberizacitrinella/countries
# https://xeno-canto.org/791900/download ./data/Emberizacitrinella/countries/Emberizacitrinella791900.mp3
# Saving file  45 / 2124 data/xeno-canto-datasetEmberizacitrinella791354.mp3
# ./data/Emberizacitrinella/countries
# https://xeno-canto.org/791354/download ./data/Emberizacitrinella/countries/Emberizacitrinella791354.mp3
# Saving file  46 / 2124 data/xeno-canto-datasetEmberizacitrinella791222.mp3
# ./data/Emberizacitrinella/countries
# https://xeno-canto.org/791222/download ./data/Emberizacitrinella/countries/Emberizacitrinella791222.mp3
# Saving file  47 / 2124 data/xeno-canto-datasetEmberizacitrinella787043.mp3
# ./data/Emberizacitrinella/countries
# https://xeno-canto.org/787043/download ./data/Emberizacitrinella/countries/Emberizacitrinella787043.mp3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 41
#      39         download(bird + ' cnt:' + country + ' type:song', bird.replace(' ', ''), country)
#      40 for bird in birds:
# ---> 41     download(bird + ' type:song', bird.replace(' ', ''), 'countries')
#
# Cell In[5], line 70, in download(searchTerms, birdName, country)
#      68 print(path)
#      69 print(fileaddress[i], path + "/" + birdName + filenamesID[i] + ".mp3")
# ---> 70 urllib.request.urlretrieve(fileaddress[i],
#      71                            path + "/" + birdName + filenamesID[i] + ".mp3")
#
# File C:\Programs\python\Lib\urllib\request.py:270, in urlretrieve(url, filename, reporthook, data)
#     267     reporthook(blocknum, bs, size)
#     269 while True:
# --> 270     block = fp.read(bs)
#     271     if not block:
#     272         break
#
# File C:\Programs\python\Lib\http\client.py:467, in HTTPResponse.read(self, amt)
#     464     return b""
#     466 if self.chunked:
# --> 467     return self._read_chunked(amt)
#     469 if amt is not None:
#     470     if self.length is not None and amt > self.length:
#     471         # clip the read to the "end of response"
#
# File C:\Programs\python\Lib\http\client.py:595, in HTTPResponse._read_chunked(self, amt)
#     592     break
#     594 if amt is not None and amt <= chunk_left:
# --> 595     value.append(self._safe_read(amt))
#     596     self.chunk_left = chunk_left - amt
#     597     break
#
# File C:\Programs\python\Lib\http\client.py:638, in HTTPResponse._safe_read(self, amt)
#     631 def _safe_read(self, amt):
#     632     """Read the number of bytes requested.
#     633
#     634     This function should be used when <amt> bytes "should" be present for
#     635     reading. If the bytes are truly not available (due to EOF), then the
#     636     IncompleteRead exception can be used to detect the problem.
#     637     """
# --> 638     data = self.fp.read(amt)
#     639     if len(data) < amt:
#     640         raise IncompleteRead(data, amt-len(data))
#
# File C:\Programs\python\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File C:\Programs\python\Lib\ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Programs\python\Lib\ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:
